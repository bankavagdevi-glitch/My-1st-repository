# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Step 1: Create the dataset
data = {
    'Outlook': ['Sunny', 'Sunny', 'Overcast', 'Rain', 'Rain', 'Rain', 'Overcast', 'Sunny', 'Sunny', 'Rain', 'Sunny', 'Overcast', 'Overcast', 'Rain'],
    'Temp': ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool', 'Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild'],
    'Humidity': ['High', 'High', 'High', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'High'],
    'Wind': ['Weak', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong', 'Strong', 'Weak', 'Strong'],
    'PlayTennis': ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
}

# Convert the data to a DataFrame
df = pd.DataFrame(data)
print(df)

# Step 2: Preprocess the data - Encode categorical variables
label_encoder = LabelEncoder()

df['Outlook'] = label_encoder.fit_transform(df['Outlook'])
df['Temp'] = label_encoder.fit_transform(df['Temp'])
df['Humidity'] = label_encoder.fit_transform(df['Humidity'])
df['Wind'] = label_encoder.fit_transform(df['Wind'])
df['PlayTennis'] = label_encoder.fit_transform(df['PlayTennis'])

# Step 3: Split the data into features and target variable
X = df[['Outlook', 'Temp', 'Humidity', 'Wind']]  # Features
y = df['PlayTennis']  # Target variable

# Step 4: Train the Decision Tree Classifier
decision_tree = DecisionTreeClassifier(criterion='entropy')
decision_tree.fit(X, y)

# Step 5 (Optional): Visualize the Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(decision_tree, feature_names=['Outlook', 'Temp', 'Humidity', 'Wind'], class_names=['No', 'Yes'], filled=True)
plt.show()

# Predicting using the trained model (Optional)
# Example: Predict whether to play tennis with a new set of conditions
prediction = decision_tree.predict([[2, 2, 1, 0]])  # Outlook=Overcast, Temp=Mild, Humidity=High, Wind=Weak
print("Prediction (0=No, 1=Yes):", prediction[0])
print(df)
# Out:
#      Outlook  Temp Humidity    Wind PlayTennis
# 0      Sunny   Hot     High    Weak         No
# 1      Sunny   Hot     High  Strong         No
# 2   Overcast   Hot     High    Weak        Yes
# 3       Rain  Mild     High    Weak        Yes
# 4       Rain  Cool   Normal    Weak        Yes
# 5       Rain  Cool   Normal  Strong         No
# 6   Overcast  Cool   Normal  Strong        Yes
# 7      Sunny  Mild     High    Weak         No
# 8      Sunny  Cool   Normal    Weak        Yes
# 9       Rain  Mild   Normal    Weak        Yes
# 10     Sunny  Mild   Normal  Strong        Yes
# 11  Overcast  Mild     High  Strong        Yes
# 12  Overcast   Hot   Normal    Weak        Yes
# 13      Rain  Mild     High  Strong         No
# Prediction (0=No, 1=Yes): 1
#     Outlook  Temp  Humidity  Wind  PlayTennis
# 0         2     1         0     1           0
# 1         2     1         0     0           0
# 2         0     1         0     1           1
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt

# Create the dataset
data = {
    'Outlook': ['Sunny', 'Sunny', 'Overcast', 'Rain', 'Rain', 'Rain', 'Overcast', 'Sunny', 'Sunny', 'Rain', 'Sunny', 'Overcast', 'Overcast', 'Rain'],
    'Temp': ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool', 'Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild'],
    'Humidity': ['High', 'High', 'High', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'High'],
    'Wind': ['Weak', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong', 'Strong', 'Weak', 'Strong'],
    'PlayTennis': ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
}

# Convert the dataset to a DataFrame
df = pd.DataFrame(data)

# Convert categorical variables to numeric using one-hot encoding
df_encoded = pd.get_dummies(df[['Outlook', 'Temp', 'Humidity', 'Wind']])
y = df['PlayTennis'].apply(lambda x: 1 if x == 'Yes' else 0)

# Train the decision tree classifier using entropy (information gain)
clf = DecisionTreeClassifier(criterion='entropy')
clf.fit(df_encoded, y)

# Plot the decision tree
plt.figure(figsize=(12,8))
tree.plot_tree(clf, feature_names=df_encoded.columns, class_names=['No', 'Yes'], filled=True)
plt.show()

# %%
#1 imported libraries
we have imported pandas for data manipulation and accessing dataframe
matplot lib for visualization
skikitlearn for importing decison tree alogorithm model and to utilize label_encoder function

#2 Giving the data
taken a data with 4 columns and 14 rows

#3 Converted the data in list format to Dataframe
using pd.Dataframe function

#4 using label_encoder
df['attribute'] = label_encoder.fit_transform(df['attribute'])
using this function,we have encoded the labels/categories as 0,1,2,3... format and transformed the data into its origiinal path and fitted the data into model

#5 splitted the data into training data and testing data
we have given 4 attributes for input i.e to train the model 
and one attribute as target variable i.e to get predicted by the algorithm

#6 Too train the Model
decision_tree = DecisionTreeClassifier(criterion='entropy')
decision_tree.fit(X, y)

using DecisionTreeClassifier model ,we have given that' on what basis ,the algorithm needed to be trained and given ''entrophy' as criteria that means ,now the alg will predict the data based on the' information gain

#7 For visualization
we have used plot_tree to visualize a decision tree on python.
given all the featured and respctive class labels and plotted the decison tree

# To give testing data
 At last, we have inputted the testing variables for prediction, as decison tree classifier doesnt take categories, we have inputted it through numbers through laber_encoder !!
 input=[[2, 2, 1, 0]]
 it indicates sunny,mild,normal,strong

so it predicted that the status of 'play tennis' is yes i.e one can play tennis outside with respect to this whether condition.
